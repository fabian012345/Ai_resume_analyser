# %%
# Import the time module to use for delays (e.g., waiting for a page to load)
import time

# Import numpy, a fundamental package for numerical computations in Python
import numpy as np

# Import pandas, a powerful data manipulation and analysis library for Python
import pandas as pd

# Import webdriver from selenium, a tool for automating web browser interaction
from selenium import webdriver

# Import By from selenium.webdriver.common.by, used to locate items on a web page
from selenium.webdriver.common.by import By

# Import Keys from selenium.webdriver.common.keys, allows sending keys to web elements (like keyboard inputs)
from selenium.webdriver.common.keys import Keys

# Import warnings library to manage warnings during runtime
import warnings

# Command to suppress all warnings, making the output cleaner and less cluttered
warnings.filterwarnings('ignore')

# %%
# Prompt the user to enter job titles separated by commas and store the input as a string
user_input = input('Enter Job Titles (comma-separated):')

# Split the string into a list at each comma to handle multiple job titles
user_input_job_title = user_input.split(',')

# Strip any leading/trailing whitespace from each job title
user_input_job_title = [title.strip() for title in user_input_job_title]

# Print the list of job titles to verify the input was processed correctly
print(user_input_job_title)
# Out:
# Enter Job Titles (comma-separated):data scientist
# ['data scientist']

# %%
user_input_job_title
# Out:
# ['data scientist']

# %%
# Initialize an empty list to store formatted job titles
formatted_job_titles = []

# Iterate through each job title in the user input list
for title in user_input_job_title:
    # Split the job title into individual words
    words = title.split()
    
    # Join the words with '%20' to replace spaces
    formatted_title = '%20'.join(words)
    
    # Append the formatted job title to the list
    formatted_job_titles.append(formatted_title)

# Join the formatted job titles with '%2C%20' to separate them in the final string
# '%2C' represents the URL-encoded comma (,) and '%20' represents the URL-encoded space ( )
final_job_title_string = '%2C%20'.join(formatted_job_titles)

# Print the final formatted job title string
print(final_job_title_string)
# Out:
# data%20scientist

# %%
link = f"https://www.linkedin.com/jobs/search/?currentJobId=3910773395&f_TPR=r604800&keywords={user_input_job_title}&location=United%20Kingdom&originalSubdomain=uk"
print(link)
# Out:
# https://www.linkedin.com/jobs/search/?currentJobId=3910773395&f_TPR=r604800&keywords=['data scientist']&location=United%20Kingdom&originalSubdomain=uk

# %%
# Create a new instance of the Chrome WebDriver, which controls the Chrome browser
driver = webdriver.Chrome()

# Maximize the browser window to ensure full visibility
driver.maximize_window()

# Open the provided link in the Chrome browser
driver.get(link)

# Set an implicit wait time of 10 seconds to wait for elements to become available
driver.implicitly_wait(10)

# %%
# Loop through the range from 0 to 1 (2 times)
for i in range(2):
    # Execute JavaScript to scroll to the bottom of the page
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
    # Pause script execution for 5 seconds to allow content to load
    time.sleep(5)

    try:
        # Find and click the "See more jobs" button using CSS selector
        x = driver.find_element(by=By.CSS_SELECTOR, value="button[aria-label='See more jobs']").click()
        
        # Pause script execution for 3 seconds after clicking the button
        time.sleep(3)
    except:
        # If the button is not found, do nothing and continue
        pass

# %%
# Initialize an empty list to store company names
company_name = []

# Try block to catch any potential exceptions
try:
    # Find all elements with CSS selector matching company names
    companies = driver.find_elements(by=By.CSS_SELECTOR, value='h4[class="base-search-card__subtitle"]')
    
    # Iterate through each found element
    for company in companies:
        # Append the text of each element to the company_name list
        company_name.append(company.text)

# Exception handling block to handle any errors
except:
    # If an exception occurs, do nothing and continue
    pass

# Print the list of company names
print(company_name)
# Out:
# ['BBC', 'Dyson', 'Torbay Pharma', 'Ralph Lauren', 'PEP Health', 'GRAYCE', 'Gopuff', 'InterEx Group', 'Kantar Media', 'Acquire Me', 'Omnis Partners', 'Energy Jobline', 'Nicholson Glover', 'Meta', 'CricViz', 'Tech Kinect', 'Meta', 'DHL Supply Chain', 'Morgan McKinley', 'GRAYCE', 'QuanTech Partners', 'Match Digital', 'Northern Powergrid', 'VRS Recruitment', 'Aviva', 'Klickstarters', 'Hunter Bond', 'Lifelancer', 'Vp plc', 'Understanding Recruitment', 'DHL Supply Chain', 'Tiro Partners Limited', 'Stanford Black Limited', 'Sixty Eight People', 'Dexter Talent', 'Houseful', 'WYK Digital', 'Energy Jobline', 'Hunter Bond', 'Ingenii Search', 'Novo Nordisk', 'NielsenIQ', 'Energy Jobline', 'Energy Jobline', 'Hunter Bond', 'Energy Jobline', 'DataCareers', 'Stott and May', 'Hunter Bond', 'Deel', 'the LEGO Group', 'Energy Jobline', 'Bamboo Crowd', 'Malaberg', 'Andretti Global', 'Nestlé', 'Lawrence Harvey', 'Elton Recruitment', 'Energy Jobline', 'KDR Talent Solutions', 'Klickstarters', 'Hunter Bond', 'Lifelancer', 'Vp plc', 'Understanding Recruitment', 'DHL Supply Chain', 'Tiro Partners Limited', 'Stanford Black Limited', 'Sixty Eight People', 'Dexter Talent', 'the LEGO Group', 'Energy Jobline', 'Bamboo Crowd', 'Malaberg', 'Andretti Global', 'Nestlé', 'Lawrence Harvey', 'Elton Recruitment', 'Energy Jobline', 'KDR Talent Solutions']

# %%
# Initialize an empty list to store job titles
job_title = []

# Try block to catch any potential exceptions
try:
    # Find all elements with CSS selector matching job titles
    titles = driver.find_elements(by=By.CSS_SELECTOR, value='h3[class="base-search-card__title"]')
    
    # Iterate through each found element
    for title in titles:
        # Append the text of each element to the job_title list
        job_title.append(title.text)

# Exception handling block to handle any errors
except:
    # If an exception occurs, do nothing and continue
    pass

# Print the list of job titles
print(job_title)
# Out:
# ['Data Analyst', 'Graduate Data Analyst', 'Data Analyst - Generic Medicine', 'Junior Machine Learning Engineer', 'Data Scientist', 'Graduate Data Analyst - Manchester', 'Data Analyst, In-Stock Management', 'Data Scientist', 'Data Scientist', 'Data Engineer Intern', 'Analyst', 'Graduate Software Engineer', 'Data Scientist | Behavioural | PR and Comms', 'Data Scientist, Product Analytics', 'Data Analyst', 'Data Scientist', 'Enterprise Engineer (University Grad)', 'Data Scientist', 'Data Scientist', 'Graduate Software Developer - Manchester', 'Quantitative Researcher [Python Developer] – London', 'Data Analyst', 'Junior Data Analyst', 'Data Scientist', 'Junior Data Scientist', 'Junior Software Engineer', 'Junior Python Developer – Elite Tech Firm (up to £80K + Bonus + Hybrid)', 'Data Analyst, Life Sciences', 'Graduate Group Data Analyst', 'Data Scientist', 'Data Scientist', 'Data Analyst', 'Python Developer', 'Data Analyst', 'Junior Data Analyst', 'Data Analyst', 'Data Analytics Trainee (14 week free bootcamp)', 'Data Scientist - Remote', 'Python Developer – Elite Fintech Company (up to £120K + Bonus + Hybrid)', 'Data Scientist', 'Molecular Data Scientist - Biologics (Fixed term Contract)', 'SQL Developer', 'Data Scientist - Remote', 'Data Scientist - Remote', 'Computer Science Graduate+1 year Python Developer : Elite Hedge Fund/Base/Bonus : London hydrid', 'Data Scientist - Remote', 'Data Analyst', 'Data Analyst', 'Graduate Software Engineer - Up to £200k comp + Benefits - Hybrid Working', 'Data Scientist', 'Data Analyst, Learning and Skills Development', 'Data Scientist - Remote', 'Data Analyst', 'Data Analyst', 'Python Developer', 'Data Scientist', 'Data Scientist', 'Data Analyst', 'Data Scientist - Remote', 'Data Analyst', 'Junior Software Engineer', 'Junior Python Developer – Elite Tech Firm (up to £80K + Bonus + Hybrid)', 'Data Analyst, Life Sciences', 'Graduate Group Data Analyst', 'Data Scientist', 'Data Scientist', 'Data Analyst', 'Python Developer', 'Data Analyst', 'Junior Data Analyst', 'Data Analyst, Learning and Skills Development', 'Data Scientist - Remote', 'Data Analyst', 'Data Analyst', 'Python Developer', 'Data Scientist', 'Data Scientist', 'Data Analyst', 'Data Scientist - Remote', 'Data Analyst']

# %%
# Initialize an empty list to store company locations
company_location = []

# Try block to catch any potential exceptions
try:
    # Find all elements with CSS selector matching company locations
    locations = driver.find_elements(by=By.CSS_SELECTOR, value='span[class="job-search-card__location"]')
    
    # Iterate through each found element
    for location in locations:
        # Append the text of each element to the company_location list
        company_location.append(location.text)

# Exception handling block to handle any errors
except:
    # If an exception occurs, do nothing and continue
    pass

# Print the list of company locations
print(company_location)
# Out:
# ['London, England, United Kingdom', 'Malmesbury, England, United Kingdom', 'United Kingdom', 'London, England, United Kingdom', 'United Kingdom', 'Manchester, England, United Kingdom', 'London, England, United Kingdom', 'Greater London, England, United Kingdom', 'London Area, United Kingdom', 'Greater London, England, United Kingdom', 'Oxfordshire, England, United Kingdom', 'London, England, United Kingdom', 'London Area, United Kingdom', 'London, England, United Kingdom', 'London Area, United Kingdom', 'London Area, United Kingdom', 'London, England, United Kingdom', 'Greater Portsmouth Area', 'London Area, United Kingdom', 'Manchester, England, United Kingdom', 'London Area, United Kingdom', 'London Area, United Kingdom', 'Dewsbury, England, United Kingdom', 'Slough, England, United Kingdom', 'Greater Bristol Area, United Kingdom', 'Birmingham, England, United Kingdom', 'Greater London, England, United Kingdom', 'London, England, United Kingdom', 'Harrogate, England, United Kingdom', 'London Area, United Kingdom', 'United Kingdom', 'London Area, United Kingdom', 'London Area, United Kingdom', 'London Area, United Kingdom', 'Liverpool, England, United Kingdom', 'London, England, United Kingdom', 'Greater London, England, United Kingdom', 'Middlesbrough, England, United Kingdom', 'Greater London, England, United Kingdom', 'London Area, United Kingdom', 'London, England, United Kingdom', 'Stockport, England, United Kingdom', 'Newcastle Upon Tyne, England, United Kingdom', 'Edinburgh, Scotland, United Kingdom', 'London Area, United Kingdom', 'Leeds, England, United Kingdom', 'West Midlands, England, United Kingdom', 'London Area, United Kingdom', 'Greater London, England, United Kingdom', 'United Kingdom', 'London, England, United Kingdom', 'Glasgow, Scotland, United Kingdom', 'London Area, United Kingdom', 'London Area, United Kingdom', 'Silverstone, England, United Kingdom', 'Crawley, England, United Kingdom', 'London Area, United Kingdom', 'Stevenage, England, United Kingdom', 'Liverpool, England, United Kingdom', 'United Kingdom', 'Birmingham, England, United Kingdom', 'Greater London, England, United Kingdom', 'London, England, United Kingdom', 'Harrogate, England, United Kingdom', 'London Area, United Kingdom', 'United Kingdom', 'London Area, United Kingdom', 'London Area, United Kingdom', 'London Area, United Kingdom', 'Liverpool, England, United Kingdom', 'London, England, United Kingdom', 'Glasgow, Scotland, United Kingdom', 'London Area, United Kingdom', 'London Area, United Kingdom', 'Silverstone, England, United Kingdom', 'Crawley, England, United Kingdom', 'London Area, United Kingdom', 'Stevenage, England, United Kingdom', 'Liverpool, England, United Kingdom', 'United Kingdom']

# %%
# Initialize an empty list to store job URLs
job_url = []

# Try block to catch any potential exceptions
try:
    # Find all elements with XPath containing URLs of job listings
    urls = driver.find_elements(by=By.XPATH, value='//a[contains(@href, "/jobs/")]')
    
    # Iterate through each found element
    for url in urls:
        # Get the 'href' attribute of each element and append it to the job_url list
        job_url.append(url.get_attribute('href'))

# Exception handling block to handle any errors
except:
    # If an exception occurs, do nothing and continue
    pass

# Print the list of job URLs
print(job_url)
# Out:
# ['https://uk.linkedin.com/jobs/view/data-analyst-at-bbc-3912068735?position=1&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=eBzRbXDgr%2BzMJweoCt%2BfaQ%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://uk.linkedin.com/jobs/view/graduate-data-analyst-at-dyson-3909010865?position=2&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=HiHMbwNPe5QjN9JqIVCvyg%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://uk.linkedin.com/jobs/view/data-analyst-generic-medicine-at-torbay-pharma-3904240943?position=3&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=XfkxymGw9B8mNSOMFHLbBg%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://uk.linkedin.com/jobs/view/junior-machine-learning-engineer-at-ralph-lauren-3853758485?position=4&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=wVuLAJ7reO7biaICYDDvfg%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://uk.linkedin.com/jobs/view/data-scientist-at-pep-health-3905997394?position=5&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=n%2FhaDqnj83JDCJZK3CY%2B8Q%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://uk.linkedin.com/jobs/view/graduate-data-analyst-manchester-at-grayce-3912067115?position=6&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=oFLRlNmuw%2FszVfXzC2GdVg%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://uk.linkedin.com/jobs/view/data-analyst-in-stock-management-at-gopuff-3900814634?position=7&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=3%2BajrZ8CZHFluhNccqmgRA%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://uk.linkedin.com/jobs/view/data-scientist-at-interex-group-3879605080?position=8&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=NFpTTknNekajGs6dHTvMCg%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://uk.linkedin.com/jobs/view/data-scientist-at-kantar-media-3905541175?position=9&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=lwsohLK81K1b7VgF%2BKzr5A%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://uk.linkedin.com/jobs/view/data-engineer-intern-at-acquire-me-3902403146?position=10&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=oEgTl6RxdB%2BdcM8YjEHdcA%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://uk.linkedin.com/jobs/view/analyst-at-omnis-partners-3911763571?position=11&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=iIPGZ8MSNc6%2FhFCYWA%2BtDw%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://uk.linkedin.com/jobs/view/graduate-software-engineer-at-energy-jobline-3909169165?position=12&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=s23gSNwwhD9t%2FUyFQtDuyQ%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://uk.linkedin.com/jobs/view/data-scientist-behavioural-pr-and-comms-at-nicholson-glover-3908285713?position=13&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=bhmevdITjd7v20Ch92F8Fw%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://uk.linkedin.com/jobs/view/data-scientist-product-analytics-at-meta-3912362497?position=14&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=YruAkTx5%2FFX%2FOSsRribgSg%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://uk.linkedin.com/jobs/view/data-analyst-at-cricviz-3910997497?position=15&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=UTsVGnKk7nU9FMMhdJQTWA%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://uk.linkedin.com/jobs/view/data-scientist-at-tech-kinect-3908891221?position=16&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=Q2wxPBRAY9JsnuTfOhcQYw%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://uk.linkedin.com/jobs/view/enterprise-engineer-university-grad-at-meta-3912361525?position=17&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=rec28JE%2BQC4vEu8t5g4FTA%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://uk.linkedin.com/jobs/view/data-scientist-at-dhl-supply-chain-3911958608?position=18&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=Bx7 ...

# %%
df = pd.DataFrame(company_name, columns=['Company Name'])
df['Job Title'] = pd.DataFrame(job_title)
df['Location'] = pd.DataFrame(company_location)
df['Website URL'] = pd.DataFrame(job_url)
df
# Out:
#             Company Name                         Job Title  \
# 0                    BBC                      Data Analyst
# 1                  Dyson             Graduate Data Analyst
# 2          Torbay Pharma   Data Analyst - Generic Medicine
# 3           Ralph Lauren  Junior Machine Learning Engineer
# 4             PEP Health                    Data Scientist
# ..                   ...                               ...
# 75                Nestlé                    Data Scientist
# 76       Lawrence Harvey                    Data Scientist
# 77     Elton Recruitment                      Data Analyst
# 78        Energy Jobline           Data Scientist - Remote
# 79  KDR Talent Solutions                      Data Analyst
#
#                                Location  \
# 0       London, England, United Kingdom
# 1   Malmesbury, England, United Kingdom
# 2                        United Kingdom
# 3       London, England, United Kingdom
# 4                        United Kingdom
# ..                                  ...
# 75     Crawley, England, United Kingdom
# 76          London Area, United Kingdom
# 77   Stevenage, England, United Kingdom
# 78   Liverpool, England, United Kingdom
# 79                       United Kingdom
#
#                                           Website URL
# 0   https://uk.linkedin.com/jobs/view/data-analyst...
# 1   https://uk.linkedin.com/jobs/view/graduate-dat...
# 2   https://uk.linkedin.com/jobs/view/data-analyst...
# 3   https://uk.linkedin.com/jobs/view/junior-machi...
# 4   https://uk.linkedin.com/jobs/view/data-scienti...
# ..                                                ...
# 75  https://uk.linkedin.com/jobs/view/data-scienti...
# 76  https://uk.linkedin.com/jobs/view/data-scienti...
# 77  https://uk.linkedin.com/jobs/view/data-analyst...
# 78  https://uk.linkedin.com/jobs/view/data-scienti...
# 79  https://uk.linkedin.com/jobs/view/data-analyst...
#
# [80 rows x 4 columns]

# %%
df.to_csv('data_scientist.csv')

# %%
def job_title_filter(x, user_input_job_title):
    # Convert user input job titles to lowercase and split into individual words
    suggestion = [word.lower() for title in user_input_job_title for word in title.split()]
    
    # Convert job title x to lowercase and split into individual words
    title_words = x.split()
    a = [word.lower() for word in title_words]
    
    # Find the intersection of words between user input job titles and job title x
    intersection = list(set(suggestion).intersection(set(a)))
    
    # Return job title x if the intersection contains more than one word, otherwise return NaN
    return x if len(intersection) > 1 else np.nan

# %%
df['Job Title'] = df['Job Title'].apply(lambda x: job_title_filter(x, user_input_job_title))
df=df.dropna()
df.reset_index(drop=True, inplace=True)
df
# Out:
#                  Company Name  \
# 0                  PEP Health
# 1               InterEx Group
# 2                Kantar Media
# 3            Nicholson Glover
# 4                 Tech Kinect
# 5            DHL Supply Chain
# 6             Morgan McKinley
# 7             VRS Recruitment
# 8                       Aviva
# 9   Understanding Recruitment
# 10           DHL Supply Chain
# 11             Energy Jobline
# 12             Ingenii Search
# 13               Novo Nordisk
# 14             Energy Jobline
# 15             Energy Jobline
# 16             Energy Jobline
# 17                       Deel
# 18             Energy Jobline
# 19                     Nestlé
# 20            Lawrence Harvey
# 21             Energy Jobline
# 22  Understanding Recruitment
# 23           DHL Supply Chain
# 24             Energy Jobline
# 25                     Nestlé
# 26            Lawrence Harvey
# 27             Energy Jobline
#
#                                             Job Title  \
# 0                                      Data Scientist
# 1                                      Data Scientist
# 2                                      Data Scientist
# 3         Data Scientist | Behavioural | PR and Comms
# 4                                      Data Scientist
# 5                                      Data Scientist
# 6                                      Data Scientist
# 7                                      Data Scientist
# 8                               Junior Data Scientist
# 9                                      Data Scientist
# 10                                     Data Scientist
# 11                            Data Scientist - Remote
# 12                                     Data Scientist
# 13  Molecular Data Scientist - Biologics (Fixed te...
# 14                            Data Scientist - Remote
# 15                            Data Scientist - Remote
# 16                            Data Scientist - Remote
# 17                                     Data Scientist
# 18                            Data Scientist - Remote
# 19                                     Data Scientist
# 20                                     Data Scientist
# 21                            Data Scientist - Remote
# 22                                     Data Scientist
# 23                                     Data Scientist
# 24                            Data Scientist - Remote
# 25                                     Data Scientist
# 26                                     Data Scientist
# 27                            Data Scientist - Remote
#
#                                         Location  \
# 0                                 United Kingdom
# 1        Greater London, England, United Kingdom
# 2                    London Area, United Kingdom
# 3                    London Area, United Kingdom
# 4                    London Area, United Kingdom
# 5                        Greater Portsmouth Area
# 6                    London Area, United Kingdom
# 7                Slough, England, United Kingdom
# 8           Greater Bristol Area, United Kingdom
# 9                    London Area, United Kingdom
# 10                                United Kingdom
# 11        Middlesbrough, England, United Kingdom
# 12                   London Area, United Kingdom
# 13               London, England, United Kingdom
# 14  Newcastle Upon Tyne, England, United Kingdom
# 15           Edinburgh, Scotland, United Kingdom
# 16                Leeds, England, United Kingdom
# 17                                United Kingdom
# 18             Glasgow, Scotland, United Kingdom
# 19              Crawley, England, United Kingdom
# 20                   London Area, United Kingdom
# 21            Liverpool, England, United Kingdom
# 22                   London Area, United Kingdom
# 23                                United Kingdom
# 24             Glasgow, Scotland, United Kingdom
# 25              Crawley, England, United Kingdom
# 26                   London Area, United Kingdom
# 27            Liverpool, England, United Kingdom
#
#                                           Website URL
# 0   https://uk.linkedin.com/jobs/view/data-scienti...
# 1   https://uk.linkedin.com/jobs/view/data-scienti...
# 2   https://uk.linkedin.com/jobs/view/data-scienti...
# 3   https://uk.linkedin.com/jobs/view/data-scienti...
# 4   https://uk.linkedin.com/jobs/view/data-scienti...
# 5   https://uk.linkedin.com/jobs/view/data-scienti...
# 6   https://uk.linkedin.com/jobs/view/data-scienti...
# 7   https://uk.linkedin.com/jobs/view/data-scienti...
# 8   https://uk.linkedin.com/jobs/view/junior-data-...
# 9   https://uk.linkedin.com/jobs/view/data-scienti...
# 10  https://uk.linkedin.com/jobs/view/data-scienti...
# 11  https://uk.linkedin.com/jobs/view/data-scienti...
# 12  https://uk.linkedin.com/jobs/view/data-scienti...
# 13  https://uk.linkedin.com/jobs/view/molecular-da...
# 14  https://uk.linkedin.com/jobs/view/data-scienti...
# 15  https://uk.linkedin.com/jobs/view/data-scienti...
# 16  https://uk.linkedin.com/jobs/view/data-scienti...
# 17  https://uk.linkedin.com/jobs/view/data-scienti...
# 18  https://uk.linkedin.com/jobs/view/data-scienti...
# 19  https://uk.linkedin.com/jobs/view/data-scienti...
# 20  https://uk.linkedin.com/jobs/view/data-scienti...
# 21  https://uk.linkedin.com/jobs/view/data-scienti...
# 22  https://uk.linkedin.com/jobs/view/data-scienti...
# 23  https://uk.linkedin.com/jobs/view/data-scienti...
# 24  https://uk.linkedin.com/jobs/view/data-scienti...
# 25  https://uk.linkedin.com/jobs/view/data-scienti...
# 26  https://uk.linkedin.com/jobs/view/data-scienti...
# 27  https://uk.linkedin.com/jobs/view/data-scienti...

# %%
df=df.iloc[:10,:]
df
# Out:
#                 Company Name                                    Job Title  \
# 0                 PEP Health                               Data Scientist
# 1              InterEx Group                               Data Scientist
# 2               Kantar Media                               Data Scientist
# 3           Nicholson Glover  Data Scientist | Behavioural | PR and Comms
# 4                Tech Kinect                               Data Scientist
# 5           DHL Supply Chain                               Data Scientist
# 6            Morgan McKinley                               Data Scientist
# 7            VRS Recruitment                               Data Scientist
# 8                      Aviva                        Junior Data Scientist
# 9  Understanding Recruitment                               Data Scientist
#
#                                   Location  \
# 0                           United Kingdom
# 1  Greater London, England, United Kingdom
# 2              London Area, United Kingdom
# 3              London Area, United Kingdom
# 4              London Area, United Kingdom
# 5                  Greater Portsmouth Area
# 6              London Area, United Kingdom
# 7          Slough, England, United Kingdom
# 8     Greater Bristol Area, United Kingdom
# 9              London Area, United Kingdom
#
#                                          Website URL
# 0  https://uk.linkedin.com/jobs/view/data-scienti...
# 1  https://uk.linkedin.com/jobs/view/data-scienti...
# 2  https://uk.linkedin.com/jobs/view/data-scienti...
# 3  https://uk.linkedin.com/jobs/view/data-scienti...
# 4  https://uk.linkedin.com/jobs/view/data-scienti...
# 5  https://uk.linkedin.com/jobs/view/data-scienti...
# 6  https://uk.linkedin.com/jobs/view/data-scienti...
# 7  https://uk.linkedin.com/jobs/view/data-scienti...
# 8  https://uk.linkedin.com/jobs/view/junior-data-...
# 9  https://uk.linkedin.com/jobs/view/data-scienti...

# %%
def description(link):
    # Open the provided link in the web driver
    driver.get(link)
    time.sleep(3)  # Adding a delay to ensure page loads completely
    
    # Click on the button to show more job descriptions
    driver.find_element(by=By.CSS_SELECTOR, value='button[data-tracking-control-name="public_jobs_show-more-html-btn"]').click()
    time.sleep(2)  # Adding a delay to allow the additional content to load
    
    # Find all elements containing job descriptions
    descriptions = driver.find_elements(by=By.CSS_SELECTOR, value='div[class="show-more-less-html__markup relative overflow-hidden"]')
    driver.implicitly_wait(4)  # Setting implicit wait time
    
    for description in descriptions:
        # Return the text of the first description found
        return description.text

# %%
# Extract website URLs from the DataFrame and convert them to a list
website_url = df['Website URL'].tolist()

# Initialize an empty list to store job descriptions
job_description = []

# Iterate through each website URL
for url in website_url:
    # Get the description data from the URL using the description function
    data = description(url)
    
    # Check if the data is not None and has non-zero length after stripping whitespace
    if data is not None and len(data.strip()) > 0:
        # Append the job description to the list if available
        job_description.append(data)
    else:
        # If description is not available, append a placeholder string
        job_description.append('Description Not Available')

# %%
df['Job Description'] = pd.DataFrame(job_description, columns=['Description'])
df
# Out:
#                 Company Name                                    Job Title  \
# 0                 PEP Health                               Data Scientist
# 1              InterEx Group                               Data Scientist
# 2               Kantar Media                               Data Scientist
# 3           Nicholson Glover  Data Scientist | Behavioural | PR and Comms
# 4                Tech Kinect                               Data Scientist
# 5           DHL Supply Chain                               Data Scientist
# 6            Morgan McKinley                               Data Scientist
# 7            VRS Recruitment                               Data Scientist
# 8                      Aviva                        Junior Data Scientist
# 9  Understanding Recruitment                               Data Scientist
#
#                                   Location  \
# 0                           United Kingdom
# 1  Greater London, England, United Kingdom
# 2              London Area, United Kingdom
# 3              London Area, United Kingdom
# 4              London Area, United Kingdom
# 5                  Greater Portsmouth Area
# 6              London Area, United Kingdom
# 7          Slough, England, United Kingdom
# 8     Greater Bristol Area, United Kingdom
# 9              London Area, United Kingdom
#
#                                          Website URL  \
# 0  https://uk.linkedin.com/jobs/view/data-scienti...
# 1  https://uk.linkedin.com/jobs/view/data-scienti...
# 2  https://uk.linkedin.com/jobs/view/data-scienti...
# 3  https://uk.linkedin.com/jobs/view/data-scienti...
# 4  https://uk.linkedin.com/jobs/view/data-scienti...
# 5  https://uk.linkedin.com/jobs/view/data-scienti...
# 6  https://uk.linkedin.com/jobs/view/data-scienti...
# 7  https://uk.linkedin.com/jobs/view/data-scienti...
# 8  https://uk.linkedin.com/jobs/view/junior-data-...
# 9  https://uk.linkedin.com/jobs/view/data-scienti...
#
#                                      Job Description
# 0  Data Scientist | Healthtech | PEP Health\nLoca...
# 1  The ideal candidate's favourite words are lear...
# 2  As people increasingly move across channels an...
# 3  🎉 Join a team committed to making a real impac...
# 4  Data Scientist Job Description:\n\nAnalyze lar...
# 5  RCS Grade: J\n\nContract Type: Permanent\n\nLo...
# 6  Exciting opportunity to work with a Big4 Tech ...
# 7  Data Scientist | Slough, Hybrid | £55,000 - £6...
# 8  Junior Data Scientist\nSalary: Circa £45,000\n...
# 9  Data Scientist | Junior - Mid level | London\n...

# %%
l = len(df['Company Name'])
for i in range(0,l):
    print(f"Company Name : {df.iloc[i,0]}")
    print(f"Job Title    : {df.iloc[i,1]}")
    print(f"Location     : {df.iloc[i,2]}")
    print(f"Website URL  : {df.iloc[i,3]}")
    print(f"Description  : {df.iloc[i,4]}")
# Out:
# Company Name : PEP Health
# Job Title    : Data Scientist
# Location     : United Kingdom
# Website URL  : https://uk.linkedin.com/jobs/view/data-scientist-at-pep-health-3905997394?position=5&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=n%2FhaDqnj83JDCJZK3CY%2B8Q%3D%3D&trk=public_jobs_jserp-result_search-card
# Description  : Data Scientist | Healthtech | PEP Health
# Location: Remote within the UK
# We are looking for a Data Scientist to join our world-class tech team and grow with us as we scale our services in the UK, US and globally, making a genuine impact on the quality of healthcare.
#  Why is it challenging & interesting?
# At PEP Health, we’re on a mission to transform healthcare through a stronger and more empowered patient voice. PEP Health listens to and makes sense of the millions of digital comments made by patients about their care to understand trends and create real-time insights. We have recently completed significant funding to grow the team and ensure our impact is international.
# As part of our tech team, you will be responsible for a variety of tasks including the modelling, analysis and presentation of both quantitative and qualitative data. You will be working closely with the commercial business to ensure the insights are impactful and reflect real-world conditions.
#  What will be your main responsibilities?
# You will work as a key part of our tech team to enhance existing NLP models, analyse the outputs of those models on the wealth of data we collect, and work closely with our customers to explain the findings in a clear, concise, and actionable manner.
# As this role encompasses data analysis and data science tasks, and translating those outputs into impactful insights for the business, the ideal candidate will be comfortable with data analysis and visualisation and promoting your work in a commercial setting.
# We are looking for someone who is excited to work in a dynamic and fast-paced start-up environment. You should be self-motivated, eager to learn, and willing to take on new responsibilities, while managing your workload.
#  Your skills and experience
# Essential:
# Experience using SQL, NLP, AWS, and implementing machine learning models
# 2+ years’ experience working directly with commercial clients to present and evolve data science solutions.
# Experience managing and developing junior data scientists.
# Strong Python skills
# Experience in carrying out data cleansing, linking, validation and quality assurance across a variety of data types.
# High attention to detail with confidence in dealing with ambiguity.
# Strong data analytical and exploratory skills
# Eagerness to take ownership and pride in documenting and maintaining your work
# Being a independent learner with good problem-solving skills, who is able to use online resources to find solutions yourself
# Excellent spoken and written communication skills
# Being proactive, approachable, and flexible
# Educated to degree level.
#  What can we offer you?
# In return for your expertise and commitment, we will provide a flexible, fast-paced, and stimulating international environment that will stretch your abilities and provide significant opportunities to learn. We also offer competitive salary and benefits combined with the ability to do rewarding work with a real-world, meaningful impact on transforming healthcare, and the opportunity to enter and help grow a promising venture from an early stage.
#  Some of the benefits of working with us include:
# Fully-remote (within the UK) and flexible working arrangements
# Unlimited leave
# Monthly wellbeing balance
# Regular national and international company meet-ups
# Being part of a friendly and welcoming team
# Mentorship and encouragement to learn and develop new skills
# Regular learning and knowledge-sharing sessions
#  PEP Health is an equal opportunities employer and we welcome applications from diverse backgrounds.
# Annual Salary: £47,500-£52,000
# Duration & Start Date: Full-Time Equivalent / Starting as soon as possible
# If you have any questions about the role, please contact Alex.Griffiths@PEPhealth.ai
#  ** Please note that we do not work with external recruiters. The domain of any recruiters contacting us about the position or to offer candidates will be blocked by PEP Health. **
# Company Name : InterEx Group
# Job Title    : Data Scientist
# Location     : Greater London, England, United Kingdom
# Website URL  : https://uk.linkedin.com/jobs/view/data-scientist-at-interex-group-3879605080?position=8&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=NFpTTknNekajGs6dHTvMCg%3D%3D&trk=public_jobs_jserp-result_search-card
# Description  : The ideal candidate's favourite words are learning, data, scale, and agility. You will leverage your strong collaboration skills and ability to extract valuable insights from highly complex data sets to ask the right questions and find the right answers.
#
# Responsibilities
# Analyze raw data: assessing quality, cleansing, and structuring for downstream processing
# Design accurate and scalable prediction algorithms
# Collaborate with the engineering team to bring analytical prototypes to production
# Generate actionable insights for business improvements
#
# Qualifications
# Bachelor's degree or equivalent experience in quantitative field (Statistics, Mathematics, Computer Science, Engineering, etc.)
# At least 1 - 2 years of experience in quantitative analytics or data modelling
# Deep understanding of predictive modelling, machine-learning, clustering and classification techniques, and algorithms
# Fluency in a programming language (Python, C,C++, Java, SQL)
# Familiarity with Big Data frameworks and visualization tools (Cassandra, Hadoop, Spark, Tableau)
# Company Name : Kantar Media
# Job Title    : Data Scientist
# Location     : London Area, United Kingdom
# Website URL  : https://uk.linkedin.com/jobs/view/data-scientist-at-kantar-media-3905541175?position=9&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=lwsohLK81K1b7VgF%2BKzr5A%3D%3D&trk=public_jobs_jserp-result_search-card
# Description  : As people increasingly move across channels and platforms, Kantar Media’s data and audience measurement, targeting, analytics and advertising intelligence services unlock insights to inform powerful decision-making.
#
# Working with panel and first-party data in over 80 countries, we have the world’s fastest growing cross-media measurement footprint, underpinned by versatility, scale, technology and expertise, to drive long-term business growth for our clients and partners.
#
# Our versatility, scale, technology, and expertise enable our 5000 people across Latin America, Europe, the Middle East, Asia Pacific, North America, and Africa to understand audiences and help the world’s leading organisations succeed and grow.
#
# Job Title: Data Scientist
# Location: London, Grays Inn Road
# Salary: Competitive
# Full time/Permanent
#
# Kantar is the leader in providing audience and advertising measurement tools and intelligence. With a track record in audience research services across 50+ countries, Kantar is at the forefront of technological developments in audience measurement in the media industry, working with broadcasters and advertisers, media agencies and industry committees. The data science team provides research and technical expertise, support, oversight, and methodological development to our global operating services and sits within the Global Product team.
#
# About the Project/Role
# The key area of focus for the role is the development and improvement of mathematical and statistical models demonstrating different data sets both at panel level and at census level. These will include Kantar’s internally owned data and data from Kantar’s global partners such as global advertisers, national and international broadcasters, and global online social media and publishing platforms.
#
# The major area of interest and development in the audience measurement space over the last few years involve the integration of multiple data sources, with a view of creating new and more complete hybrid datasets. These data sets combine TV and digital advertising platforms information and use the accuracy of panel-based data together with the breath and extension of census level information.
#
# The goal is to have individual-level information across advertising platforms and media, providing all the usual features such as demographic reach and frequency estimates for highly granular and accurate viewing insight, without the limitations of panel sizes.
# Job Role Requirements
# Design and refine machine learning and statistical models to improve their performance and adaptability.
# Develop prototypes of statistical and machine learning models in Python, ensuring they integrate seamlessly into existing data pipelines.
# Work collaboratively with data scientists, product managers, project managers, and software engineers to align project goals and optimise product development.
# Write detailed requirement documents and practical guides to facilitate the engineering team in deploying models into production environments efficiently.
# Conduct thorough data investigations to ensure the quality and completeness of datasets and oversee quality control measures for modelling outcomes.
# Actively engage in team knowledge-sharing sessions and deliver presentations to discuss findings, insights, and methodologies across the team and broader organisation.
#
# Role Requirements
# Very strong mathematical and statistical skills, and with a passion for the development and implementation of new models.
# Programming and data analysis experience in Python
# Skilled in working with large and complex datasets with a keen eye for detail and accuracy.
# Experienced in working independently.
# An ability to demonstrate analysing data and looking for stories, patterns, trends, and insights.
# A PhD/master’s degree in a quantitative, mathematical, or scientific subject area.
# Alternatively, equivalent experience in a commercial and data science setting
# At Kantar we have an integrated way of rewarding our people based around a simple, clear, and consistent set of principles. Our approach helps to ensure we are market competitive and to support a pay for performance culture, where your reward and career progression opportunities are linked to what you deliver.
# We go beyond the obvious, using intelligence, passion, and creativity to inspire new thinking and shape the world we live in. Apply for a career that’s out of the ordinary and join us.
# We want to create an equality of opportunity in a fair and supportive working environment where people feel included, accepted, and are allowed to flourish in a space where their mental health and wellbeing is taken into consideration. We want to create a more diverse community to expand our talent pool, be locally representative, drive diversity of thinking and better commercial outcomes.
# At Kantar, the diversity of our employees provides a richer environment for our employees and broader depth and breadth of thinking for our clients. Kantar is committed to inclusion and diversity; therefore, we welcome applications from all sections of society and do not discriminate based on age, race, religion, gender, pregnancy, sexual orientation, gender identity, disability, marital status, or any other legally protected characteristics.
#
# Privacy and Legal Statement
#
# PRIVACY DISCLOSURE: Please note that by applying to this opportunity you consent to the personal data you provide to us to be processed and retained by The Kantar Group Limited (“Kantar”). Your details will be kept on our Internal ATS (Applicant Tracking System) for as long as is necessary for the purposes of recruitment, which may include your details being shared with the hiring manager(s) and for consideration for potential future opportunities by Kantar and its affiliate Kantar group companies. For full details of our privacy policy please visit www.kantar.com
# Company Name : Nicholson Glover
# Job Title    : Data Scientist | Behavioural | PR and Comms
# Location     : London Area, United Kingdom
# Website URL  : https://uk.linkedin.com/jobs/view/data-scientist-behavioural-pr-and-comms-at-nicholson-glover-3908285713?position=13&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=bhmevdITjd7v20Ch92F8Fw%3D%3D&trk=public_jobs_jserp-result_search-card
# Description  : 🎉 Join a team committed to making a real impact in the world! 🌍
#
# Are you passionate about using the power of communication to tackle the biggest challenges of our time? Do you thrive on uncovering insights and transforming data into compelling stories? If so, we've got the perfect role for you!
#
# At our PR and Communications agency, we're all about building a better world through intelligent and creative communications.
#
# From healthcare to technology to environmental sustainability, we partner with organizations dedicated to making a positive difference. And we're looking for a Behavioural Data Analyst to join our Insights Practice and help us drive meaningful change.
#
# Here's what you'll be doing:
# Using cutting-edge analytical techniques to understand human behaviour and inform client strategies
# Crafting compelling narratives and actionable recommendations from complex data sets
# Collaborating with a talented international team to deliver top-notch client work
# What we're looking for:
# A data wizard with a knack for storytelling and a passion for making a difference
# Experience using Python for data science, with a minimum of two years in the industry
# Experience of using ML models and NLP, webscraping for data collection
# Strong statistical analysis skills (clustering, dimensionality reduction, regression) and the ability to apply them to real-world business problems
# Excellent communication skills, both in presenting insights and building relationships with clients
# Plus, if you've got experience with open data, SQL, or PowerBI, that's a bonus!
# Ready to join a purpose-driven team where your voice is heard, and your work makes a difference? Apply now and let's build a better world together! 🚀
# Company Name : Tech Kinect
# Job Title    : Data Scientist
# Location     : London Area, United Kingdom
# Website URL  : https://uk.linkedin.com/jobs/view/data-scientist-at-tech-kinect-3908891221?position=16&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=Q2wxPBRAY9JsnuTfOhcQYw%3D%3D&trk=public_jobs_jserp-result_search-card
# Description  : Data Scientist Job Description:
#
# Analyze large and complex data sets using statistical methods and machine learning techniques to uncover insights and patterns that drive business decisions.
# Develop and implement predictive models, algorithms, and statistical analyses to solve complex business problems and optimize processes.
# Clean, preprocess, and transform raw data into a usable format for analysis, ensuring data quality and integrity.
# Collaborate with cross-functional teams to understand business objectives and translate them into data-driven solutions.
# Identify and define key performance indicators (KPIs) and metrics to measure the effectiveness and success of data-driven initiatives.
# Design and conduct experiments and A/B tests to evaluate the impact of different strategies and interventions.
# Communicate complex data-driven findings and insights to both technical and non-technical stakeholders through visualizations, reports, and presentations.
# Stay up-to-date with the latest advancements in data science, machine learning, and artificial intelligence to continuously improve modeling techniques and methodologies.
# Collaborate with data engineers and IT teams to ensure data infrastructure, storage, and retrieval systems are optimized for data analysis and modeling.
# Apply data privacy and security best practices to ensure compliance with regulations and protect sensitive information.
# Mentor and provide guidance to junior data scientists, sharing best practices and fostering a culture of continuous learning and development.
# Company Name : DHL Supply Chain
# Job Title    : Data Scientist
# Location     : Greater Portsmouth Area
# Website URL  : https://uk.linkedin.com/jobs/view/data-scientist-at-dhl-supply-chain-3911958608?position=18&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=Bx7FjvO1vj4Q%2FlNgsS41Pw%3D%3D&trk=public_jobs_jserp-result_search-card
# Description  : RCS Grade: J
#
# Contract Type: Permanent
#
# Location: Remote (with occasional national travel)
#
# Closing date: 3rd May 2024
#
# DHL, an award-winning leading supply chain business is seeking an experienced Data Scientist to play a vital role driving a continuous improvement culture which empowers our people to deliver value to our stakeholders. As a Data Scientist at DHL Supply Chain, you will play a key role in driving data-driven insights and innovations to optimize our supply chain operations. You will work closely with cross-functional teams to take ownership for end-to-end development, deployment, and monitoring of advanced analytics models and solutions that address complex business challenges.
#
# WHAT DOES THE ROLE ENTAIL?
#
# As part of your normal duties, you will:
#
#
# Support the definition of project contents, deliverables, and timelines of data analytics projects
# Collaborate with business stakeholders to understand their requirements and translate them into actionable data science solutions
# Apply advanced analytics techniques to analyse large data sets and identify patterns, trends, and insights in consultation with the project lead
# Apply statistics and machine learning techniques to develop predictive models for decision-making and to optimize processes, improve operational efficiency, and drive cost savings
# Jointly deploy models into production with data/software engineers
# Support in on-boarding and coaching of junior data science colleagues
# Liaise with other experts cross-functionally to share best practices
# Stay up-to-date with the latest advancements in data science and identify opportunities to apply new techniques and technologies
#
#
# WHAT DO WE NEED FROM YOU?
#
#
# Previous hands-on experience in Data Science, delivering machine learning models to production - within a supply chain business preferred
# Bachelor's or Master's degree in a STEM field such as Data Science, Statistics, Computer Science, Mathematics, or Engineering – or equivalent
# Proficiency in Python and relevant data science libraries (NumPy, pandas, scikit-learn etc.)
# Experience with SQL, Power BI, Git & GitHub
# Strong knowledge of Machine Learning Algorithms and respective theory
# Ability to work within a team, collaborating effectively with colleagues
# Strong stakeholder management skills and the ability to influence
# A drive to learn new technologies and techniques
# Experience with Azure, Spark (PySpark) Kubeflow - desirable
#
#
# WHY CHOOSE US?
#
# As well as competitive pay rates, you will be entitled to an award-winning range of benefits including:
#
#
# Access to our company car scheme or car allowance
# Free confidential 24/7 GP service
# Hundreds of discounts (including retail, childcare + gym)
# Affordable loans & enhanced pension scheme
# 24/7 employee support service for you (+ family) with access to free counselling and much more: https://careers.dhl.com/global/en/dsc-benefits
#
#
# OUR APPROACH TO DIVERSITY & INCLUSION
#
# We will ensure that all our resourcing activities are fair, transparent and consistent across the UK. Find out more about our global approach to Diversity, Equity, Inclusion & Belonging: https://careers.dhl.com/global/en/diversity
#
# Be An Essential Part Of Everyday Life
#
# DHL is the global leader in Supply Chain management and we keep the world moving. Our expert teams work together to deliver for our customers across a range of industries including retail, automotive, healthcare and more, so they can deliver to their customers.
#
# #UKIDSCWellBeing
# Company Name : Morgan McKinley
# Job Title    : Data Scientist
# Location     : London Area, United Kingdom
# Website URL  : https://uk.linkedin.com/jobs/view/data-scientist-at-morgan-mckinley-3907438837?position=19&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=WNf%2FYuebmDdMW5a1B6xyLw%3D%3D&trk=public_jobs_jserp-result_search-card
# Description  : Exciting opportunity to work with a Big4 Tech company as a Data Scientist, based in London!
#
# 12 months contract
#
# Key Qualifications:
# • Postgraduate degree (MS or PhD) in a quantitative field of study including economics, statistics, applied mathematics, data science, business, or a related discipline.
# • 5-7 years professional experience developing advanced Tableau data visualizations, dashboards and reporting.
# • Programming skills in SQL and Python required to develop and maintain custom ETL processes.
# • Skills in exploratory data analysis and familiarity with advanced quantitative analysis.
# • Experience reporting on web analytics in Adobe, or other web analytics tools.
# • Comfortable using modern data technologies. Familiarity with database modelling and data warehousing principles (Snowflake preferred).
# • Knowledge of the digital advertising industry, the mobile app economy or related field.
# • Familiarity with automated data ingestion processes including APIs.
# • Ability to partner effectively with data science and engineering stakeholders to meet the data needs of the business, translating business needs into analytical requirements.
# • Ability to communicate the results of analyses in a clear and effective manner.
# • Excellent written, verbal, presentation and communication skills.
# • Self-motivated and proactive with proven creative, problem-solving, and critical thinking capabilities.
#
# Description:
# • Support the Marketing and Sales teams with customer insights and analytics that inform and fulfill strategic objectives and goals.
# • Provide Web analytics support to Marketing stakeholders (e.g. producing ad-hoc custom dashboards and Keynote analyses supporting stakeholders).
# • Ensure operational excellence by maintaining and improving existing insights development and web reporting processes.
# • Quantify the impact of marketing initiatives on customer success and future behavior.
# • Drive business analytics projects through all phases, including data quality, data analysis, data visualization, and presentation of results and deliverables.
# • Monitor usage metrics, understanding business-based explanations for large scale trends and patterns in customer lifecycle behavior.
# • Develop data models and analytical tools for ongoing audience segmentation, benchmarking, trending and competitive analysis.
# • Build dashboards, reports and presentations.
# • Collaborate with cross-functional team, including Marketing, Sales, Data Insights and Engineering.
# Design, conduct and analyze A/B tests to optimize performance of marketing campaigns.
# Company Name : VRS Recruitment
# Job Title    : Data Scientist
# Location     : Slough, England, United Kingdom
# Website URL  : https://uk.linkedin.com/jobs/view/data-scientist-at-vrs-recruitment-3911752857?position=24&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=vh5PTkPgtM7YmJuFYJbifA%3D%3D&trk=public_jobs_jserp-result_search-card
# Description  : Data Scientist | Slough, Hybrid | £55,000 - £65,000
#
# A highly rewarding role awaits a motivated and creative Data Scientist seeking an excellent career progression opportunity. You will be joining a leading global biopharmaceutical company that specialises in the development of novel therapeutics for autoimmune and neurological diseases!
#
# Responsibilities:
# and implement advanced data science solutions, using AI and machine leaning, with internal and external data to support drug discovery
# collaboratively with experimental and computational scientists
# strong background in biologics to establish analytical workflow and optimise AI methodologies
# analyse and interpret poly-omic data from across the company portfolio
#
# Experience:
# (or equivalent experience) in Computer Science, Computational Biology or a related field
# in a range of programming languages such as Python or R
# understanding of starting principles in statistics, data mining and visualisation of biological data (omics, NGS, and assay data)
# in integrative analysis of multiple omic data types including advanced statistical, machine learning and deep learning methods (large language models would be highly advantageous)
# domain knowledge, with a focus on antibodies is highly desirable
#
# Apply now for the chance to join an award-winning Research & Development organisation and make your impact on the global scientific community!
#
# Key Words: Data, Big Data, Bioinformatics, Programming, R, Python, Statistical, Data Mining, Data Visualisation, HPC Unix, Cloud-based, Computational, Deep Learning, Machine Learning, Biological, Biopharma, Biopharmaceutical, Drug Discovery, Omics, Poly-Omics, Target ID, Target Validation, Biomarker Discovery, Oxford, Hertfordshire, Wiltshire, Berkshire, Oxford, Reading, London, Slough, VRS8706MF
# Company Name : Aviva
# Job Title    : Junior Data Scientist
# Location     : Greater Bristol Area, United Kingdom
# Website URL  : https://uk.linkedin.com/jobs/view/junior-data-scientist-at-aviva-3908865576?position=25&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=cHP4LLselQMUQJ90GjY2Cw%3D%3D&trk=public_jobs_jserp-result_search-card
# Description  : Junior Data Scientist
# Salary: Circa £45,000
#
# Are you starting out in your career in AI and machine learning or are taking the next step? Are you interested in using machine learning to solve real problems in people’s lives?
# We are looking for top Data Science talent to be part of our incredible journey and as we grow our world-class Customer Science team. Aviva is not just any old insurer.
#
# The industry is ripe for disruption and that is just what we are doing. Over the past 2 years we have been on one of the most visionary digital transformation journeys of any company, and we continue to transform the way our 16m+ customers engage with our products and services, by reinventing our ways of working and consistently innovating.
# It’s certainly not your stereotype ‘insurance company’ of boring offices and grey suits. We work in agile, collaborative, cross-functional teams, with a real passion for helping customers defy uncertainty.
#
# This role is based in Bristol.
#
# A bit about the job:
#
# Within Aviva is our very special team – the Customer Science Team. We believe that everything is better when we put the customer first and data science helps us do that at massive scale. Our AI/ML data scientists are responsible for the creation and delivery of extraordinary customer-first data products and identifying new and existing data sources and data science techniques to generate best-in-class models, insights and understanding.
#
# You will be creating productionised models using our MLOps framework in addition to creating and sharing knowledge, developing team capability and collaboration as well as developing innovative approaches and solutions to problems.
# We have been recognised as the Best Place to Work in Data in 2019 and 2020 by DataIQ.
#
# Skills and experience we’re looking for:
#
# Be educated to degree level in a mathematical- or programming-oriented subject, (Computer Science, Applied Science etc), or able to demonstrate equivalent knowledge and experience. Post-graduate qualification a plus but not essential.
# Have knowledge and experience in machine learning techniques and approaches (e.g., supervised / unsupervised/reinforcement learning) and indicators of model accuracy.
# Be able to communicate complex technical concepts to specialist / non-specialist audiences.
# Have programming expertise in Python.
# As a bonus, experience with of Git-based code version control, building data pipelines with Spark or productionising Machine Learning models.
#
# What you’ll get for this role:
#
# Our purpose - with you today, for a better tomorrow – is a promise we make to our colleagues too. And one of the ways we live up to that promise is by investing in you. We have so much to offer when it comes to being an Aviva colleague.
#
# Salary: Circa £45,000 (location, skills, experience, and qualifications)
# Bonus opportunity of 8% of annual salary (actual amount depends on your performance and Aviva’s)
# Generous pension scheme - Aviva will contribute up to 14%, depending on what you put in.
# 29 days holiday plus bank holidays, and you can choose to buy or sell up to 5 days.
# Make your money go further - Up to 40% discount on Aviva products, and other retailer discounts.
# Up to £1,200 of free Aviva shares per year through our Matching Share Plan and share in the success of Aviva with our Save As You Earn scheme.
# Brilliantly supportive policies including parental and carer’s leave.
# Flexible benefits to suit you, including sustainability options such as cycle to work.
# Make a difference, be part of our Aviva Communities and use your 3 paid volunteering days to help others
# We take your wellbeing seriously with lots of support and tools.
#
# Take a look to learn more. Put a salary into this calculator to see what your total Aviva Reward could be.
#
# Aviva is for everyone:
#
# We are inclusive and welcome everyone – we want applications from people with diverse backgrounds and experiences.
#
# Excited but not sure you tick every box? Research tells us that women, particularly, feel this way. So, regardless of gender, why not apply. And if you’re in a job share just apply as a pair.
#
# We flex locations, hours and working patterns to suit our customers, business, and you. Most of our people are smart working –spending around 50% of their time in our offices every week - combining the benefits of flexibility with time together with colleagues.
#
# To find out more about working at Aviva take a look here
#
# We interview every disabled applicant who meets the minimum criteria for the job. Once you’ve applied, please send us an email stating that you have a disclosed disability, and we’ll interview you.
#
# We’d love it if you could submit your application online. If you require an alternative method of applying, please give Sahra Abdulla a call on 07775 042 835 or send an email to sahra.abdulla@aviva.com.
# Company Name : Understanding Recruitment
# Job Title    : Data Scientist
# Location     : London Area, United Kingdom
# Website URL  : https://uk.linkedin.com/jobs/view/data-scientist-at-understanding-recruitment-3906651827?position=30&pageNum=0&refId=y01c0%2FNnL5Xfno9b1leqeQ%3D%3D&trackingId=vKydeQTxPCtVaucn3LwuqA%3D%3D&trk=public_jobs_jserp-result_search-card
# Description  : Data Scientist | Junior - Mid level | London
#
# Are you driven by the potential of data to revolutionise healthcare? This is a fantastic developmental opportunity for an aspiring Data Scientist to join an innovative healthcare focused business.
#
# What you can expect:
#
# Utilise your experience in R and SQL to extract, transform and analyse complex healthcare datasets
# Collaborate with cross-functional teams to design and implement machine learning models for predictive analytics and decision-making
# Develop interactive and user-friendly data visualisation tools
#
# What we'd love to see:
#
# A degree in Computer Science, Statistics, Mathematics or related discipline
# Proficiency in R Shiny
# SQL for data manipulation and analysis
#
# What's in it for you:
#
# Salary of up to £45,000 + comprehensive benefits package
# Opportunity to work at the intersection of data science and healthcare
# Collaborative and inclusive working environment with ample opportunity for professional growth and development
#
# Candidates must be able to work in the London office a couple of days a week.
#
# Please apply now for immediate consideration.
